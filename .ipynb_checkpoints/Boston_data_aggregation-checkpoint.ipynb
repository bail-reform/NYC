# %%
# pip install geopandas
import pandas as pd
import geopandas as gpd
import re
from shapely.geometry import Point

# Load the CSV file into a pandas DataFrame
file_path = '/Users/yujinlee/Google_Drive/NYU/Fall_2023/Capstone/CrimeData'
df_2018 = pd.read_csv(file_path + '/boston_2018.csv', low_memory = False)
df_2019 = pd.read_csv(file_path + '/boston_2019.csv', low_memory = False)
df_2020 = pd.read_csv(file_path + '/boston_2020.csv', low_memory = False)
df_2021 = pd.read_csv(file_path + '/boston_2021.csv', low_memory = False)
df_2022 = pd.read_csv(file_path + '/boston_2022.csv', low_memory = False)
df_2023 = pd.read_csv(file_path + '/boston_2023.csv', low_memory = False)

# %% [markdown]
# Crime Data: https://data.boston.gov/dataset/crime-incident-reports-august-2015-to-date-source-new-system/resource/313e56df-6d77-49d2-9c49-ee411f10cf58
# <br>ACS Data: https://data.census.gov/table/ACSDP5Y2022.DP05?q=population&g=050XX00US36005$8600000,36047$8600000,36061$8600000,36081$8600000,36085$8600000

# %%
combined_df = pd.concat([df_2018, df_2019, df_2020, df_2021, df_2022, df_2023], ignore_index=True)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472976 entries, 0 to 472975
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      472976 non-null  object
#  1   OFFENSE_CODE         472976 non-null  int64
#  2   OFFENSE_CODE_GROUP   98888 non-null   object
#  3   OFFENSE_DESCRIPTION  472976 non-null  object
#  4   DISTRICT             469628 non-null  object
#  5   REPORTING_AREA       472976 non-null  object
#  6   SHOOTING             374490 non-null  object
#  7   OCCURRED_ON_DATE     472976 non-null  object
#  8   YEAR                 472976 non-null  int64
#  9   MONTH                472976 non-null  int64
#  10  DAY_OF_WEEK          472976 non-null  object
#  11  HOUR                 472976 non-null  int64
#  12  UCR_PART             98868 non-null   object
#  13  STREET               470679 non-null  object
#  14  Lat                  448945 non-null  float64
#  15  Long                 448945 non-null  float64
#  16  Location             448945 non-null  object
# dtypes: float64(2), int64(4), object(11)
# memory usage: 61.3+ MB

# %%
combined_df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP    OFFENSE_DESCRIPTION  \
# 0      I192074715          2629         Harassment             HARASSMENT
# 1      I192068538          1107              Fraud  FRAUD - IMPERSONATION
# 2      I192005657          2610              Other            TRESPASSING
# 3      I192075335          3208      Property Lost     PROPERTY - MISSING
# 4      I192013179           619            Larceny     LARCENY ALL OTHERS
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0       B2            278      NaN  2018-01-01 00:00:00  2018      1
# 1      D14            794      NaN  2018-01-01 00:00:00  2018      1
# 2      C11            396      NaN  2018-01-01 00:00:00  2018      1
# 3       D4            132      NaN  2018-01-01 00:00:00  2018      1
# 4      C11            360      NaN  2018-01-01 00:00:00  2018      1
#
#   DAY_OF_WEEK  HOUR    UCR_PART            STREET        Lat       Long  \
# 0      Monday     0    Part Two      HARRISON AVE  42.331538 -71.080157
# 1      Monday     0    Part Two     GLENVILLE AVE  42.349780 -71.134230
# 2      Monday     0    Part Two      MELBOURNE ST  42.291093 -71.065945
# 3      Monday     0  Part Three  COMMONWEALTH AVE  42.353522 -71.072838
# 4      Monday     0    Part One   CENTERVALE PARK  42.296323 -71.063569
#
#                       Location
# 0  (42.33153805, -71.08015661)
# 1  (42.34977988, -71.13423049)
# 2  (42.29109287, -71.06594539)
# 3  (42.35352153, -71.07283786)
# 4  (42.29632282, -71.06356881)

# %%
combined_df.columns = combined_df.columns.str.lower()

# %%
combined_df['year'].unique()
# Out:
# array([2018, 2019, 2020, 2021, 2022, 2023])

# %%
combined_df['occurred_on_date'].isnull().mean()
# Out:
# 0.0

# %%
combined_df.head()
# Out:
#   incident_number  offense_code offense_code_group    offense_description  \
# 0      I192074715          2629         Harassment             HARASSMENT
# 1      I192068538          1107              Fraud  FRAUD - IMPERSONATION
# 2      I192005657          2610              Other            TRESPASSING
# 3      I192075335          3208      Property Lost     PROPERTY - MISSING
# 4      I192013179           619            Larceny     LARCENY ALL OTHERS
#
#   district reporting_area shooting     occurred_on_date  year  month  \
# 0       B2            278      NaN  2018-01-01 00:00:00  2018      1
# 1      D14            794      NaN  2018-01-01 00:00:00  2018      1
# 2      C11            396      NaN  2018-01-01 00:00:00  2018      1
# 3       D4            132      NaN  2018-01-01 00:00:00  2018      1
# 4      C11            360      NaN  2018-01-01 00:00:00  2018      1
#
#   day_of_week  hour    ucr_part            street        lat       long  \
# 0      Monday     0    Part Two      HARRISON AVE  42.331538 -71.080157
# 1      Monday     0    Part Two     GLENVILLE AVE  42.349780 -71.134230
# 2      Monday     0    Part Two      MELBOURNE ST  42.291093 -71.065945
# 3      Monday     0  Part Three  COMMONWEALTH AVE  42.353522 -71.072838
# 4      Monday     0    Part One   CENTERVALE PARK  42.296323 -71.063569
#
#                       location
# 0  (42.33153805, -71.08015661)
# 1  (42.34977988, -71.13423049)
# 2  (42.29109287, -71.06594539)
# 3  (42.35352153, -71.07283786)
# 4  (42.29632282, -71.06356881)

# %%
combined_df['occurred_on_date'] = combined_df['occurred_on_date'].str.slice(0, 10)

# %%
combined_df['lat'].isnull().mean()
# Out:
# 0.0508080748283211

# %%
combined_df['long'].isnull().mean()
# Out:
# 0.0508080748283211

# %%
combined_df[combined_df['long'].isnull()].shape
# Out:
# (24031, 17)

# %%
combined_df = combined_df.dropna(subset=['long'])

# %%
file_path_geo = '/Users/yujinlee/Google_Drive/NYU/Fall_2023/Capstone/CrimeData/ZIP_Codes.geojson'

zipcode = gpd.read_file(file_path_geo)
zipcode.head()
# Out:
#    OBJECTID   ZIP5   ShapeSTArea  ShapeSTLength  \
# 0         1  02134  3.721936e+07   40794.182396
# 1         2  02125  6.476052e+07   62224.521440
# 2         3  02110  6.637284e+06   18358.213496
# 3         4  02118  3.116158e+07   32353.407618
# 4         5  02126  6.078585e+07   45488.394711
#
#                                             geometry
# 0  POLYGON ((-71.12340 42.36421, -71.12345 42.364...
# 1  POLYGON ((-71.04541 42.32381, -71.04579 42.323...
# 2  POLYGON ((-71.05109 42.36418, -71.05109 42.364...
# 3  POLYGON ((-71.06315 42.34689, -71.06433 42.347...
# 4  POLYGON ((-71.09670 42.29095, -71.09692 42.290...

# %%
def create_point_from_string(coord_str):
    match = re.match(r'\(([^,]+), ([^)]+)\)', coord_str)
    if match:
        lat, lon = map(float, match.groups())
        return Point(lon, lat)
    return None

# %%
combined_df['geometry'] = combined_df['location'].apply(create_point_from_string)

# %%
combined_df.head()
# Out:
#   incident_number  offense_code offense_code_group    offense_description  \
# 0      I192074715          2629         Harassment             HARASSMENT
# 1      I192068538          1107              Fraud  FRAUD - IMPERSONATION
# 2      I192005657          2610              Other            TRESPASSING
# 3      I192075335          3208      Property Lost     PROPERTY - MISSING
# 4      I192013179           619            Larceny     LARCENY ALL OTHERS
#
#   district reporting_area shooting occurred_on_date  year  month day_of_week  \
# 0       B2            278      NaN       2018-01-01  2018      1      Monday
# 1      D14            794      NaN       2018-01-01  2018      1      Monday
# 2      C11            396      NaN       2018-01-01  2018      1      Monday
# 3       D4            132      NaN       2018-01-01  2018      1      Monday
# 4      C11            360      NaN       2018-01-01  2018      1      Monday
#
#    hour    ucr_part            street        lat       long  \
# 0     0    Part Two      HARRISON AVE  42.331538 -71.080157
# 1     0    Part Two     GLENVILLE AVE  42.349780 -71.134230
# 2     0    Part Two      MELBOURNE ST  42.291093 -71.065945
# 3     0  Part Three  COMMONWEALTH AVE  42.353522 -71.072838
# 4     0    Part One   CENTERVALE PARK  42.296323 -71.063569
#
#                       location                          geometry
# 0  (42.33153805, -71.08015661)  POINT (-71.08015661 42.33153805)
# 1  (42.34977988, -71.13423049)  POINT (-71.13423049 42.34977988)
# 2  (42.29109287, -71.06594539)  POINT (-71.06594539 42.29109287)
# 3  (42.35352153, -71.07283786)  POINT (-71.07283786 42.35352153)
# 4  (42.29632282, -71.06356881)  POINT (-71.06356881 42.29632282)

# %%
gdf = gpd.GeoDataFrame(combined_df, geometry='geometry')

# %%
gdf.head()
# Out:
#   incident_number  offense_code offense_code_group    offense_description  \
# 0      I192074715          2629         Harassment             HARASSMENT
# 1      I192068538          1107              Fraud  FRAUD - IMPERSONATION
# 2      I192005657          2610              Other            TRESPASSING
# 3      I192075335          3208      Property Lost     PROPERTY - MISSING
# 4      I192013179           619            Larceny     LARCENY ALL OTHERS
#
#   district reporting_area shooting occurred_on_date  year  month day_of_week  \
# 0       B2            278      NaN       2018-01-01  2018      1      Monday
# 1      D14            794      NaN       2018-01-01  2018      1      Monday
# 2      C11            396      NaN       2018-01-01  2018      1      Monday
# 3       D4            132      NaN       2018-01-01  2018      1      Monday
# 4      C11            360      NaN       2018-01-01  2018      1      Monday
#
#    hour    ucr_part            street        lat       long  \
# 0     0    Part Two      HARRISON AVE  42.331538 -71.080157
# 1     0    Part Two     GLENVILLE AVE  42.349780 -71.134230
# 2     0    Part Two      MELBOURNE ST  42.291093 -71.065945
# 3     0  Part Three  COMMONWEALTH AVE  42.353522 -71.072838
# 4     0    Part One   CENTERVALE PARK  42.296323 -71.063569
#
#                       location                    geometry
# 0  (42.33153805, -71.08015661)  POINT (-71.08016 42.33154)
# 1  (42.34977988, -71.13423049)  POINT (-71.13423 42.34978)
# 2  (42.29109287, -71.06594539)  POINT (-71.06595 42.29109)
# 3  (42.35352153, -71.07283786)  POINT (-71.07284 42.35352)
# 4  (42.29632282, -71.06356881)  POINT (-71.06357 42.29632)

# %%
gdf.set_crs(epsg=4326, inplace=True)
zipcode.set_crs(epsg=4326, inplace=True)
result = gpd.sjoin(gdf, zipcode, how="left", op='within')
# Out:
# /Users/yujinlee/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3309: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
result.head()
# Out:
#   incident_number  offense_code offense_code_group    offense_description  \
# 0      I192074715          2629         Harassment             HARASSMENT
# 1      I192068538          1107              Fraud  FRAUD - IMPERSONATION
# 2      I192005657          2610              Other            TRESPASSING
# 3      I192075335          3208      Property Lost     PROPERTY - MISSING
# 4      I192013179           619            Larceny     LARCENY ALL OTHERS
#
#   district reporting_area shooting occurred_on_date  year  month  ...  \
# 0       B2            278      NaN       2018-01-01  2018      1  ...
# 1      D14            794      NaN       2018-01-01  2018      1  ...
# 2      C11            396      NaN       2018-01-01  2018      1  ...
# 3       D4            132      NaN       2018-01-01  2018      1  ...
# 4      C11            360      NaN       2018-01-01  2018      1  ...
#
#              street        lat       long                     location  \
# 0      HARRISON AVE  42.331538 -71.080157  (42.33153805, -71.08015661)
# 1     GLENVILLE AVE  42.349780 -71.134230  (42.34977988, -71.13423049)
# 2      MELBOURNE ST  42.291093 -71.065945  (42.29109287, -71.06594539)
# 3  COMMONWEALTH AVE  42.353522 -71.072838  (42.35352153, -71.07283786)
# 4   CENTERVALE PARK  42.296323 -71.063569  (42.29632282, -71.06356881)
#
#                      geometry  index_right OBJECTID   ZIP5   ShapeSTArea  \
# 0  POINT (-71.08016 42.33154)         10.0     11.0  02119  4.451150e+07
# 1  POINT (-71.13423 42.34978)          0.0      1.0  02134  3.721936e+07
# 2  POINT (-71.06595 42.29109)         16.0     17.0  02124  8.565805e+07
# 3  POINT (-71.07284 42.35352)         23.0     24.0  02116  1.911765e+07
# 4  POINT (-71.06357 42.29632)         16.0     17.0  02124  8.565805e+07
#
#    ShapeSTLength
# 0   37680.702099
# 1   40794.182396
# 2   57673.007747
# 3   23262.912273
# 4   57673.007747
#
# [5 rows x 23 columns]

# %%
result.set_index('occurred_on_date', inplace=True)

# %%
result.index = pd.to_datetime(result.index)

# %%
result.head()
# Out:
#                  incident_number  offense_code offense_code_group  \
# occurred_on_date
# 2018-01-01            I192074715          2629         Harassment
# 2018-01-01            I192068538          1107              Fraud
# 2018-01-01            I192005657          2610              Other
# 2018-01-01            I192075335          3208      Property Lost
# 2018-01-01            I192013179           619            Larceny
#
#                     offense_description district reporting_area shooting  \
# occurred_on_date
# 2018-01-01                   HARASSMENT       B2            278      NaN
# 2018-01-01        FRAUD - IMPERSONATION      D14            794      NaN
# 2018-01-01                  TRESPASSING      C11            396      NaN
# 2018-01-01           PROPERTY - MISSING       D4            132      NaN
# 2018-01-01           LARCENY ALL OTHERS      C11            360      NaN
#
#                   year  month day_of_week  ...            street        lat  \
# occurred_on_date                           ...
# 2018-01-01        2018      1      Monday  ...      HARRISON AVE  42.331538
# 2018-01-01        2018      1      Monday  ...     GLENVILLE AVE  42.349780
# 2018-01-01        2018      1      Monday  ...      MELBOURNE ST  42.291093
# 2018-01-01        2018      1      Monday  ...  COMMONWEALTH AVE  42.353522
# 2018-01-01        2018      1      Monday  ...   CENTERVALE PARK  42.296323
#
#                        long                     location  \
# occurred_on_date
# 2018-01-01       -71.080157  (42.33153805, -71.08015661)
# 2018-01-01       -71.134230  (42.34977988, -71.13423049)
# 2018-01-01       -71.065945  (42.29109287, -71.06594539)
# 2018-01-01       -71.072838  (42.35352153, -71.07283786)
# 2018-01-01       -71.063569  (42.29632282, -71.06356881)
#
#                                     geometry index_right OBJECTID   ZIP5  \
# occurred_on_date
# 2018-01-01        POINT (-71.08016 42.33154)        10.0     11.0  02119
# 2018-01-01        POINT (-71.13423 42.34978)         0.0      1.0  02134
# 2018-01-01        POINT (-71.06595 42.29109)        16.0     17.0  02124
# 2018-01-01        POINT (-71.07284 42.35352)        23.0     24.0  02116
# 2018-01-01        POINT (-71.06357 42.29632)        16.0     17.0  02124
#
#                    ShapeSTArea ShapeSTLength
# occurred_on_date
# 2018-01-01        4.451150e+07  37680.702099
# 2018-01-01        3.721936e+07  40794.182396
# 2018-01-01        8.565805e+07  57673.007747
# 2018-01-01        1.911765e+07  23262.912273
# 2018-01-01        8.565805e+07  57673.007747
#
# [5 rows x 22 columns]

# %%
weekly_data = result.groupby('ZIP5').resample('W').size().reset_index(name='total_count')

# %%
weekly_data['ZIP5'].unique().shape
# Out:
# (33,)

# %%
threshold_date = pd.to_datetime('2023-05-31')

# %%
weekly_data = weekly_data[weekly_data['occurred_on_date'] <= threshold_date]

# %%
mean_counts_by_zip = weekly_data.groupby('ZIP5')['total_count'].mean().reset_index()

# %%
mean_counts_by_zip
# Out:
#      ZIP5  total_count
# 0   02108    18.879433
# 1   02109    14.741135
# 2   02110    16.014184
# 3   02111    30.326241
# 4   02113     9.450355
# 5   02114    45.872340
# 6   02115    33.280142
# 7   02116    58.712766
# 8   02118   102.056738
# 9   02119   123.241135
# 10  02120    26.113475
# 11  02121    82.507092
# 12  02122    91.088652
# 13  02124   120.964539
# 14  02125    74.237589
# 15  02126    83.868794
# 16  02127    67.666667
# 17  02128    64.741135
# 18  02129    29.602837
# 19  02130    67.790780
# 20  02131    41.851064
# 21  02132    38.730496
# 22  02134    31.010638
# 23  02135    66.971631
# 24  02136    62.751773
# 25  02151     0.872340
# 26  02152     0.062069
# 27  02163     0.225926
# 28  02199    10.421986
# 29  02203     2.167857
# 30  02210    11.712766
# 31  02215    27.925532
# 32  02467     1.748227

# %%
weekly_data['total_count'].mean()
# Out:
# 44.89677771709449

# %%
weekly_data.to_csv(file_path + '/boston_weekly_data.csv', index=False)

# %% [markdown]
# ### Run from here!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
file_path = '/Users/yujinlee/Google_Drive/NYU/Fall_2023/Capstone/CrimeData'
weekly_data = pd.read_csv(file_path + '/boston_weekly_data.csv', low_memory = False)

# %%
weekly_data.head()
# Out:
#    ZIP5 occurred_on_date  total_count
# 0  2108       2018-01-07           12
# 1  2108       2018-01-14           16
# 2  2108       2018-01-21           18
# 3  2108       2018-01-28           16
# 4  2108       2018-02-04           15

# %%
pop = pd.read_csv(file_path + '/boston_2022_acs.csv', low_memory = False)
pop.head()
# Out:
#            GEO_ID                  NAME  \
# 0       Geography  Geographic Area Name
# 1  860Z200US01001           ZCTA5 01001
# 2  860Z200US01002           ZCTA5 01002
# 3  860Z200US01003           ZCTA5 01003
# 4  860Z200US01005           ZCTA5 01005
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                    16045
# 2                                    22992
# 3                                    11989
# 4                                     4837
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                             946
# 2                                             308
# 3                                             205
# 4                                             465
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                           7872
# 2                                          11654
# 3                                           5680
# 4                                           2230
#
#                                           DP05_0002M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                622
# 2                                                488
# 3                                                381
# 4                                                294
#
#                                         DP05_0003E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Female
# 1                                             8173
# 2                                            11338
# 3                                             6309
# 4                                             2607
#
#                                           DP05_0003M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                608
# 2                                                540
# 3                                                450
# 4                                                344
#
#                                           DP05_0004E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Sex r...
# 1                                               96.3
# 2                                              102.8
# 3                                               90.0
# 4                                               85.5
#
#                                           DP05_0004M  ...  \
# 0  Margin of Error!!SEX AND AGE!!Total population...  ...
# 1                                                9.4  ...
# 2                                                8.8  ...
# 3                                               12.1  ...
# 4                                               15.4  ...
#
#                                          DP05_0087PM  \
# 0  Percent Margin of Error!!HISPANIC OR LATINO AN...
# 1                                                0.8
# 2                                                1.4
# 3                                                1.2
# 4                                                0.9
#
#                     DP05_0088PE                                   DP05_0088PM  \
# 0  Percent!!Total housing units  Percent Margin of Error!!Total housing units
# 1                           (X)                                           (X)
# 2                           (X)                                           (X)
# 3                           (X)                                           (X)
# 4                           (X)                                           (X)
#
#                                          DP05_0089PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                              12646
# 2                                              18046
# 3                                              10352
# 4                                               3979
#
#                                          DP05_0089PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          DP05_0090PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               48.1
# 2                                               50.9
# 3                                               48.4
# 4                                               44.2
#
#                                          DP05_0090PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                2.6
# 2                                                2.5
# 3                                                3.5
# 4                                                5.6
#
#                                          DP05_0091PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               51.9
# 2                                               49.1
# 3                                               51.6
# 4                                               55.8
#
#                                          DP05_0091PM Unnamed: 366
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...          NaN
# 1                                                2.6          NaN
# 2                                                2.5          NaN
# 3                                                3.5          NaN
# 4                                                5.6          NaN
#
# [5 rows x 367 columns]

# %%
pop.columns = pop.iloc[0]
pop = pop[1:]
pop.head()
# Out:
# 0       Geography Geographic Area Name  \
# 1  860Z200US01001          ZCTA5 01001
# 2  860Z200US01002          ZCTA5 01002
# 3  860Z200US01003          ZCTA5 01003
# 4  860Z200US01005          ZCTA5 01005
# 5  860Z200US01007          ZCTA5 01007
#
# 0 Estimate!!SEX AND AGE!!Total population  \
# 1                                   16045
# 2                                   22992
# 3                                   11989
# 4                                    4837
# 5                                   15368
#
# 0 Margin of Error!!SEX AND AGE!!Total population  \
# 1                                            946
# 2                                            308
# 3                                            205
# 4                                            465
# 5                                             59
#
# 0 Estimate!!SEX AND AGE!!Total population!!Male  \
# 1                                          7872
# 2                                         11654
# 3                                          5680
# 4                                          2230
# 5                                          7406
#
# 0 Margin of Error!!SEX AND AGE!!Total population!!Male  \
# 1                                                622
# 2                                                488
# 3                                                381
# 4                                                294
# 5                                                326
#
# 0 Estimate!!SEX AND AGE!!Total population!!Female  \
# 1                                            8173
# 2                                           11338
# 3                                            6309
# 4                                            2607
# 5                                            7962
#
# 0 Margin of Error!!SEX AND AGE!!Total population!!Female  \
# 1                                                608
# 2                                                540
# 3                                                450
# 4                                                344
# 5                                                336
#
# 0 Estimate!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)  \
# 1                                               96.3
# 2                                              102.8
# 3                                               90.0
# 4                                               85.5
# 5                                               93.0
#
# 0 Margin of Error!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)  \
# 1                                                9.4
# 2                                                8.8
# 3                                               12.1
# 4                                               15.4
# 5                                                8.0
#
# 0  ...  \
# 1  ...
# 2  ...
# 3  ...
# 4  ...
# 5  ...
#
# 0 Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Two or More Races!!Two races excluding Some Other Race, and three or more races  \
# 1                                                0.8
# 2                                                1.4
# 3                                                1.2
# 4                                                0.9
# 5                                                0.9
#
# 0 Percent!!Total housing units Percent Margin of Error!!Total housing units  \
# 1                          (X)                                          (X)
# 2                          (X)                                          (X)
# 3                          (X)                                          (X)
# 4                          (X)                                          (X)
# 5                          (X)                                          (X)
#
# 0 Percent!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population  \
# 1                                              12646
# 2                                              18046
# 3                                              10352
# 4                                               3979
# 5                                              12247
#
# 0 Percent Margin of Error!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
# 5                                                (X)
#
# 0 Percent!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Male  \
# 1                                               48.1
# 2                                               50.9
# 3                                               48.4
# 4                                               44.2
# 5                                               47.0
#
# 0 Percent Margin of Error!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Male  \
# 1                                                2.6
# 2                                                2.5
# 3                                                3.5
# 4                                                5.6
# 5                                                2.1
#
# 0 Percent!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Female  \
# 1                                               51.9
# 2                                               49.1
# 3                                               51.6
# 4                                               55.8
# 5                                               53.0
#
# 0 Percent Margin of Error!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Female  \
# 1                                                2.6
# 2                                                2.5
# 3                                                3.5
# 4                                                5.6
# 5                                                2.1
#
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# 5 NaN
#
# [5 rows x 367 columns]

# %%
pop.columns = pop.columns.str.lower()
pop.columns = pop.columns.str.replace(' ', '_')
pop.head()
# Out:
# 0       geography geographic_area_name  \
# 1  860Z200US01001          ZCTA5 01001
# 2  860Z200US01002          ZCTA5 01002
# 3  860Z200US01003          ZCTA5 01003
# 4  860Z200US01005          ZCTA5 01005
# 5  860Z200US01007          ZCTA5 01007
#
# 0 estimate!!sex_and_age!!total_population  \
# 1                                   16045
# 2                                   22992
# 3                                   11989
# 4                                    4837
# 5                                   15368
#
# 0 margin_of_error!!sex_and_age!!total_population  \
# 1                                            946
# 2                                            308
# 3                                            205
# 4                                            465
# 5                                             59
#
# 0 estimate!!sex_and_age!!total_population!!male  \
# 1                                          7872
# 2                                         11654
# 3                                          5680
# 4                                          2230
# 5                                          7406
#
# 0 margin_of_error!!sex_and_age!!total_population!!male  \
# 1                                                622
# 2                                                488
# 3                                                381
# 4                                                294
# 5                                                326
#
# 0 estimate!!sex_and_age!!total_population!!female  \
# 1                                            8173
# 2                                           11338
# 3                                            6309
# 4                                            2607
# 5                                            7962
#
# 0 margin_of_error!!sex_and_age!!total_population!!female  \
# 1                                                608
# 2                                                540
# 3                                                450
# 4                                                344
# 5                                                336
#
# 0 estimate!!sex_and_age!!total_population!!sex_ratio_(males_per_100_females)  \
# 1                                               96.3
# 2                                              102.8
# 3                                               90.0
# 4                                               85.5
# 5                                               93.0
#
# 0 margin_of_error!!sex_and_age!!total_population!!sex_ratio_(males_per_100_females)  \
# 1                                                9.4
# 2                                                8.8
# 3                                               12.1
# 4                                               15.4
# 5                                                8.0
#
# 0  ...  \
# 1  ...
# 2  ...
# 3  ...
# 4  ...
# 5  ...
#
# 0 percent_margin_of_error!!hispanic_or_latino_and_race!!total_population!!not_hispanic_or_latino!!two_or_more_races!!two_races_excluding_some_other_race,_and_three_or_more_races  \
# 1                                                0.8
# 2                                                1.4
# 3                                                1.2
# 4                                                0.9
# 5                                                0.9
#
# 0 percent!!total_housing_units percent_margin_of_error!!total_housing_units  \
# 1                          (X)                                          (X)
# 2                          (X)                                          (X)
# 3                          (X)                                          (X)
# 4                          (X)                                          (X)
# 5                          (X)                                          (X)
#
# 0 percent!!citizen,_voting_age_population!!citizen,_18_and_over_population  \
# 1                                              12646
# 2                                              18046
# 3                                              10352
# 4                                               3979
# 5                                              12247
#
# 0 percent_margin_of_error!!citizen,_voting_age_population!!citizen,_18_and_over_population  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
# 5                                                (X)
#
# 0 percent!!citizen,_voting_age_population!!citizen,_18_and_over_population!!male  \
# 1                                               48.1
# 2                                               50.9
# 3                                               48.4
# 4                                               44.2
# 5                                               47.0
#
# 0 percent_margin_of_error!!citizen,_voting_age_population!!citizen,_18_and_over_population!!male  \
# 1                                                2.6
# 2                                                2.5
# 3                                                3.5
# 4                                                5.6
# 5                                                2.1
#
# 0 percent!!citizen,_voting_age_population!!citizen,_18_and_over_population!!female  \
# 1                                               51.9
# 2                                               49.1
# 3                                               51.6
# 4                                               55.8
# 5                                               53.0
#
# 0 percent_margin_of_error!!citizen,_voting_age_population!!citizen,_18_and_over_population!!female  \
# 1                                                2.6
# 2                                                2.5
# 3                                                3.5
# 4                                                5.6
# 5                                                2.1
#
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# 5 NaN
#
# [5 rows x 367 columns]

# %%
pop['geographic_area_name'] = pop['geographic_area_name'].str.slice(6, 11)

# %%
pop = pop.rename(columns={'geographic_area_name': 'ZIP5'})

# %%
pop = pop.iloc[:, [1, 2]]

# %%
weekly_data['ZIP5'] = weekly_data['ZIP5'].astype(str).str.zfill(5)

# %%
merged_df = pd.merge(weekly_data, pop, on='ZIP5', how='left')
merged_df.head()
# Out:
#     ZIP5 occurred_on_date  total_count estimate!!sex_and_age!!total_population
# 0  02108       2018-01-07           12                                    4218
# 1  02108       2018-01-14           16                                    4218
# 2  02108       2018-01-21           18                                    4218
# 3  02108       2018-01-28           16                                    4218
# 4  02108       2018-02-04           15                                    4218

# %%
merged_df = merged_df.rename(columns={'estimate!!sex_and_age!!total_population': 'total_population'})

# %%
merged_df.head()
# Out:
#     ZIP5 occurred_on_date  total_count total_population
# 0  02108       2018-01-07           12             4218
# 1  02108       2018-01-14           16             4218
# 2  02108       2018-01-21           18             4218
# 3  02108       2018-01-28           16             4218
# 4  02108       2018-02-04           15             4218

# %%
merged_df['total_population'] = pd.to_numeric(merged_df['total_population'].str.replace(',', ''), errors='coerce').astype(int)
merged_df['crime_rate'] = (merged_df['total_count'] / merged_df['total_population']) * 10000
merged_df = merged_df.rename(columns={'occurred_on_date': 'week'})

# %%
merged_df = merged_df[merged_df['total_population'] != 0]

# %%
merged_df.head()
# Out:
#     ZIP5        week  total_count  total_population  crime_rate
# 0  02108  2018-01-07           12              4218   28.449502
# 1  02108  2018-01-14           16              4218   37.932670
# 2  02108  2018-01-21           18              4218   42.674253
# 3  02108  2018-01-28           16              4218   37.932670
# 4  02108  2018-02-04           15              4218   35.561878

# %%
merged_df['week'] = pd.to_datetime(merged_df['week'])

# %%
merged_df.to_csv(file_path + '/boston_weekly_data_rate.csv', index=False)

# %%
import pandas as pd

file_path = '/Users/yujinlee/Google_Drive/NYU/Fall_2023/Capstone/CrimeData'

merged_df = pd.read_csv(file_path + '/boston_weekly_data_rate.csv')

# %%
df_plot = merged_df

# %%
df_plot.set_index('week', inplace=True)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt


# Plotting
plt.figure(figsize=(12, 8))
plt.plot(df_plot.index, df_plot['crime_rate'], marker='o', linestyle='None', color='b', markersize=1)

plt.title('Crime Rates Over Time')
plt.xlabel('Week')
plt.ylabel('Crime Rate')
plt.show()

# %%
# zoom in
plt.figure(figsize=(12, 8))
plt.plot(df_plot.index, df_plot['crime_rate'], marker='o', linestyle='None', color='b', markersize=1)

plt.ylim(0, 50)

plt.title('Crime Rates Over Time')
plt.xlabel('Year')
plt.ylabel('Crime Rate')
plt.grid(True, linewidth=0.5)
plt.show()

# %%
merged_df.head()
# Out:
#             ZIP5  total_count  total_population  crime_rate
# week
# 2018-01-07  2108           12              4218   28.449502
# 2018-01-14  2108           16              4218   37.932670
# 2018-01-21  2108           18              4218   42.674253
# 2018-01-28  2108           16              4218   37.932670
# 2018-02-04  2108           15              4218   35.561878

# %%
merged_df['ZIP5'] = merged_df['ZIP5'].astype(str).str.zfill(5)
merged_df = pd.read_csv(file_path + '/boston_weekly_data_rate.csv')

# %%
statistics = merged_df.describe().T

# Display the descriptive statistics
print(statistics)
# Out:
#                    count          mean           std     min          25%  \
# ZIP5              8875.0   2143.914366     64.503501  2108.0  2116.000000
# total_count       8875.0     46.244845     37.357601     0.0    16.000000
# total_population  8875.0  23938.816113  15452.389700  1221.0  8417.000000
# crime_rate        8875.0     24.797943     21.452336     0.0    12.642567
#
#                            50%           75%           max
# ZIP5               2126.000000   2135.000000   2467.000000
# total_count          38.000000     70.000000    220.000000
# total_population  24705.000000  31903.000000  60592.000000
# crime_rate           18.845912     33.266009    196.560197

# %%
merged_df['ZIP5'].nunique()
# Out:
# 32

# %%
print(merged_df['total_count'].median())
print(merged_df['total_population'].median())
print(merged_df['total_count'].median())
# Out:
# 38.0
# 24705.0
# 38.0

# %%
merged_df['total_count'].sum()/merged_df.groupby('ZIP5')['total_population'].first().sum()
# Out:
# 0.5381015937613082

# %%
merged_df.head(4)
# Out:
#    ZIP5        week  total_count  total_population  crime_rate
# 0  2108  2018-01-07           12              4218   28.449502
# 1  2108  2018-01-14           16              4218   37.932670
# 2  2108  2018-01-21           18              4218   42.674253
# 3  2108  2018-01-28           16              4218   37.932670

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 8))
plt.plot(df_plot.index, df_plot['crime_rate'], marker='o', linestyle='None', color='b', markersize=1)
plt.ylim(0, 50)

plt.title('Crime Rates Over Time')
plt.xlabel('Week')
plt.ylabel('Crime Rate')
plt.grid(True)
plt.show()

# %%
df_plot_temp = df_plot.reset_index()

# %%
df_plot_temp.head()
# Out:
#          week   ZIP5  total_count  total_population  crime_rate
# 0  2018-01-07  02108           12              4218   28.449502
# 1  2018-01-14  02108           16              4218   37.932670
# 2  2018-01-21  02108           18              4218   42.674253
# 3  2018-01-28  02108           16              4218   37.932670
# 4  2018-02-04  02108           15              4218   35.561878

# %%
df_plot_temp = df_plot_temp.sort_values(by='week').reset_index()

# %%
df_plot_temp['week'] = pd.to_datetime(df_plot_temp['week'])

# %%
min_date = df_plot_temp['week'].min()
df_plot_temp['week_no'] = ((df_plot_temp['week'] - min_date).dt.days // 7) + 1

# %%
x = np.arange(len(df_plot_temp['week_no'])).reshape(-1, 1)
y = df_plot_temp['crime_rate']

# Fit linear regression
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

# Plotting
plt.figure(figsize=(12, 8))
plt.plot(df_plot_temp['week_no'], y, marker='o', linestyle='None', color='b', markersize=1, label='Actual Data')
plt.plot(df_plot_temp['week_no'], y_pred, color='r', label='Trendline')

plt.title('Crime Rates Over Time')
plt.xlabel('Week')
plt.ylabel('Crime Rate')
plt.grid(True, linewidth=0.5)
plt.legend()
plt.show()

# %% [markdown]
# # Covariate Analysis

# %%
import pandas as pd
file_path = '/Users/yujinlee/Google_Drive/NYU/Fall_2023/Capstone/CrimeData'

# %% [markdown]
# ## S2301 Employment

# %%
employment = pd.read_csv(file_path + '/control/boston/ACSST5Y2018.S2301-Data.csv', low_memory=False)
employment = employment[['NAME', 'S2301_C03_001E', 'S2301_C04_001E']]
employment = employment.iloc[1:].reset_index(drop=True)
employment.columns = ['ZCTA5CE10', 'e/pop', 'un_rate']
employment['ZCTA5CE10'] = employment['ZCTA5CE10'].str.replace('ZCTA5 ', '')
employment.head()
# Out:
#   ZCTA5CE10 e/pop un_rate
# 0     01431  64.0     5.0
# 1     01432  73.8     2.4
# 2     01434  18.2     6.6
# 3     01450  63.5     4.1
# 4     01460  66.3     4.6

# %%
employment.shape
# Out:
# (295, 3)

# %% [markdown]
# # S1701 poverty

# %%
poverty = pd.read_csv(file_path + '/control/boston/ACSST5Y2018.S1701-Data.csv', low_memory=False)
poverty = poverty[['NAME', 'S1701_C03_001E']]
poverty = poverty.iloc[1:].reset_index(drop=True)
poverty.columns = ['ZCTA5CE10', 'p_rate']
poverty['ZCTA5CE10'] = poverty['ZCTA5CE10'].str.replace('ZCTA5 ', '')
poverty.head()
# Out:
#   ZCTA5CE10 p_rate
# 0     01001    9.0
# 1     01002   28.7
# 2     01003   79.3
# 3     01005    6.9
# 4     01007    5.3

# %%
poverty.shape
# Out:
# (538, 2)

# %% [markdown]
# # S1901 Household Income

# %%
income = pd.read_csv(file_path + '/control/boston/ACSST5Y2018.S1901-Data.csv', low_memory=False)
income = income[['NAME', 'S1901_C01_012E', 'S1901_C01_013E']]
income = income.iloc[1:].reset_index(drop=True)
income.columns = ['ZCTA5CE10', 'in_median', 'in_mean']
income['ZCTA5CE10'] = income['ZCTA5CE10'].str.replace('ZCTA5 ', '')
income.head()
# Out:
#   ZCTA5CE10 in_median in_mean
# 0     01001     62144   78870
# 1     01002     55858   85653
# 2     01003    2,500-       N
# 3     01005     68278   94293
# 4     01007     93300  114222

# %%
income.shape
# Out:
# (538, 3)

# %%
income.dtypes
# Out:
# ZCTA5CE10        object
# 2018in_median    object
# 2018in_mean      object
# dtype: object

# %% [markdown]
# # COVID data

# %%
import pandas as pd

# %%
file_path = '/Users/yujinlee/Google_Drive/NYU/Fall_2023/Capstone/CrimeData'
covid = pd.read_csv(file_path + '/control/boston/Weekly_Town_COVID19_MA-1.csv')
covid.head()
# Out:
#        Town      weekd  total_cases  weekly_cases
# 0  Abington  4/14/2020         54.0           NaN
# 1  Abington  4/22/2020         78.0          24.0
# 2  Abington  4/29/2020        143.0          65.0
# 3  Abington   5/6/2020        177.0          34.0
# 4  Abington  5/13/2020        190.0          13.0

# %%
covid = covid[covid['Town'] == 'Boston']

# Step 2: Convert 'weekd' to the specified date format
covid['weekd'] = pd.to_datetime(covid['weekd']).dt.strftime('%Y-%m-%d')

# Step 3: Rename 'weekd' to 'week'
covid.rename(columns={'weekd': 'week'}, inplace=True)

# Step 4: Drop the 'total_cases' column
covid = covid.drop('total_cases', axis=1)

# Step 5: Convert NaN to 0
covid['weekly_cases'] = covid['weekly_cases'].fillna(0).astype(int)

# Display the first few rows of the final dataframe
covid.head()
# Out:
#         Town        week  weekly_cases
# 1435  Boston  2020-04-14             0
# 1436  Boston  2020-04-22          2135
# 1437  Boston  2020-04-29          2540
# 1438  Boston  2020-05-06          1445
# 1439  Boston  2020-05-13           822

# %%
covid.to_csv(file_path + '/control/boston/boston_covid_clean.csv', index=False)

# %% [markdown]
# # Merge Data

# %%
merged_df = pd.read_csv(file_path + '/boston_weekly_data_rate.csv')
merged_df.rename(columns={'ZIP5': 'ZCTA5CE10'}, inplace=True)
merged_df['ZCTA5CE10'] = merged_df['ZCTA5CE10'].astype(str).str.zfill(5)
merged_df.head()
# Out:
#   ZCTA5CE10        week  total_count  total_population  crime_rate
# 0     02108  2018-01-07           12              4218   28.449502
# 1     02108  2018-01-14           16              4218   37.932670
# 2     02108  2018-01-21           18              4218   42.674253
# 3     02108  2018-01-28           16              4218   37.932670
# 4     02108  2018-02-04           15              4218   35.561878

# %%
#create a year variable
merged_df['week'] = pd.to_datetime(merged_df['week'])
merged_df['year'] = merged_df['week'].dt.year

# %%
merged_df.head()
# Out:
#   ZCTA5CE10       week  total_count  total_population  crime_rate  year
# 0     02108 2018-01-07           12              4218   28.449502  2018
# 1     02108 2018-01-14           16              4218   37.932670  2018
# 2     02108 2018-01-21           18              4218   42.674253  2018
# 3     02108 2018-01-28           16              4218   37.932670  2018
# 4     02108 2018-02-04           15              4218   35.561878  2018

# %%
merged_df = pd.merge(merged_df, employment, on='ZCTA5CE10', how='left')

# %%
merged_df = pd.merge(merged_df, poverty, on='ZCTA5CE10', how='left')
merged_df.head()
# Out:
#   ZCTA5CE10       week  total_count  total_population  crime_rate  year e/pop  \
# 0     02108 2018-01-07           12              4218   28.449502  2018  61.2
# 1     02108 2018-01-14           16              4218   37.932670  2018  61.2
# 2     02108 2018-01-21           18              4218   42.674253  2018  61.2
# 3     02108 2018-01-28           16              4218   37.932670  2018  61.2
# 4     02108 2018-02-04           15              4218   35.561878  2018  61.2
#
#   un_rate p_rate
# 0     8.3   10.8
# 1     8.3   10.8
# 2     8.3   10.8
# 3     8.3   10.8
# 4     8.3   10.8

# %%
merged_df = pd.merge(merged_df, income, on='ZCTA5CE10', how='left')
merged_df.head()
# Out:
#   ZCTA5CE10       week  total_count  total_population  crime_rate  year e/pop  \
# 0     02108 2018-01-07           12              4218   28.449502  2018  61.2
# 1     02108 2018-01-14           16              4218   37.932670  2018  61.2
# 2     02108 2018-01-21           18              4218   42.674253  2018  61.2
# 3     02108 2018-01-28           16              4218   37.932670  2018  61.2
# 4     02108 2018-02-04           15              4218   35.561878  2018  61.2
#
#   un_rate p_rate in_median in_mean
# 0     8.3   10.8    136667  222479
# 1     8.3   10.8    136667  222479
# 2     8.3   10.8    136667  222479
# 3     8.3   10.8    136667  222479
# 4     8.3   10.8    136667  222479

# %%
merged_df['week'] = pd.to_datetime(merged_df['week'])
covid['week'] = pd.to_datetime(covid['week'])

# %%
min_date = crime_df['week'].min()
covid['week_no'] = ((covid['week'] - min_date).dt.days // 7) + 1
covid = covid.drop(columns=['Town','week'], axis=1)
covid.head()
# Out:
#       weekly_cases  week_no
# 1435             0      119
# 1436          2135      120
# 1437          2540      121
# 1438          1445      122
# 1439           822      123

# %%
min_date = merged_df['week'].min()
merged_df['week_no'] = ((merged_df['week'] - min_date).dt.days // 7) + 1
merged_df.head()
# Out:
#   ZCTA5CE10       week  total_count  total_population  crime_rate  year e/pop  \
# 0     02108 2018-01-07           12              4218   28.449502  2018  61.2
# 1     02108 2018-01-14           16              4218   37.932670  2018  61.2
# 2     02108 2018-01-21           18              4218   42.674253  2018  61.2
# 3     02108 2018-01-28           16              4218   37.932670  2018  61.2
# 4     02108 2018-02-04           15              4218   35.561878  2018  61.2
#
#   un_rate p_rate in_median in_mean  week_no
# 0     8.3   10.8    136667  222479        1
# 1     8.3   10.8    136667  222479        2
# 2     8.3   10.8    136667  222479        3
# 3     8.3   10.8    136667  222479        4
# 4     8.3   10.8    136667  222479        5

# %%
merged_df = pd.merge(merged_df, covid, on=['week_no'], how='left').fillna(0)
merged_df.head()
# Out:
#   ZCTA5CE10       week  total_count  total_population  crime_rate  year e/pop  \
# 0     02108 2018-01-07           12              4218   28.449502  2018  61.2
# 1     02108 2018-01-14           16              4218   37.932670  2018  61.2
# 2     02108 2018-01-21           18              4218   42.674253  2018  61.2
# 3     02108 2018-01-28           16              4218   37.932670  2018  61.2
# 4     02108 2018-02-04           15              4218   35.561878  2018  61.2
#
#   un_rate p_rate in_median in_mean  week_no  weekly_cases
# 0     8.3   10.8    136667  222479        1           0.0
# 1     8.3   10.8    136667  222479        2           0.0
# 2     8.3   10.8    136667  222479        3           0.0
# 3     8.3   10.8    136667  222479        4           0.0
# 4     8.3   10.8    136667  222479        5           0.0

# %%
rows_with_na = merged_df[merged_df.isna().any(axis=1)]
rows_with_na
# Out:
# Empty DataFrame
# Columns: [ZCTA5CE10, week, total_count, total_population, crime_rate, year, e/pop, un_rate, p_rate, in_median, in_mean, week_no, weekly_cases]
# Index: []

# %%
merged_df[merged_df['in_median']== '-']
# Out:
# Empty DataFrame
# Columns: [ZCTA5CE10, week, total_count, total_population, crime_rate, year, e/pop, un_rate, p_rate, in_median, in_mean, week_no, weekly_cases]
# Index: []

# %%
crime_df = merged_df

crime_df['in_median'] = crime_df['in_median'].astype(float)
crime_df['in_mean'] = crime_df['in_median'].astype(float)

crime_df['p_rate'] = pd.to_numeric(crime_df['p_rate'], errors='coerce')
crime_df['un_rate'] = pd.to_numeric(crime_df['un_rate'], errors='coerce')

# %%
crime_df.to_csv(file_path + '/clean/boston_weekly_data_with_covariates.csv', index=False)

# %%
crime_df.describe()
# Out:
#        total_count  total_population   crime_rate         year      un_rate  \
# count  8875.000000       8875.000000  8875.000000  8875.000000  8875.000000
# mean     46.244845      23938.816113    24.797943  2020.253183     6.785814
# std      37.357601      15452.389700    21.452336     1.573247     3.480305
# min       0.000000       1221.000000     0.000000  2018.000000     0.800000
# 25%      16.000000       8417.000000    12.642567  2019.000000     4.500000
# 50%      38.000000      24705.000000    18.845912  2020.000000     6.000000
# 75%      70.000000      31903.000000    33.266009  2022.000000     9.200000
# max     220.000000      60592.000000   196.560197  2023.000000    14.600000
#
#             p_rate      in_median        in_mean      week_no  weekly_cases
# count  8875.000000    8875.000000    8875.000000  8875.000000   8875.000000
# mean     19.094028   78010.667493   78010.667493   142.556620    170.271549
# std       9.839081   34988.691844   34988.691844    81.104626    638.066524
# min       2.300000   30551.000000   30551.000000     1.000000      0.000000
# 25%      11.600000   52474.000000   52474.000000    72.000000      0.000000
# 50%      18.000000   65250.000000   65250.000000   143.000000      0.000000
# 75%      24.800000  100915.000000  100915.000000   213.000000      0.000000
# max      40.200000  163068.000000  163068.000000   282.000000   5879.000000

# %% [markdown]
# # Regression

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
model = smf.ols('crime_rate ~ week_no + p_rate + un_rate + in_median + weekly_cases', data=crime_df).fit()
crime_df['y_hat'] = model.predict(crime_df)
print(crime_df['y_hat'].mean())
print(model.summary())
# Out:
# 24.797942795497683
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             crime_rate   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.092
# Method:                 Least Squares   F-statistic:                     225.2
# Date:                Fri, 01 Mar 2024   Prob (F-statistic):          2.12e-184
# Time:                        21:44:25   Log-Likelihood:                -39373.
# No. Observations:                8875   AIC:                         7.876e+04
# Df Residuals:                    8870   BIC:                         7.879e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        6.2500      1.544      4.048      0.000       3.223       9.277
# week_no         -0.0370      0.003    -13.817      0.000      -0.042      -0.032
# p_rate           0.8764      0.040     21.674      0.000       0.797       0.956
# un_rate         -1.2690      0.094    -13.518      0.000      -1.453      -1.085
# in_median        0.0002   1.04e-05     19.411      0.000       0.000       0.000
# weekly_cases          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                     3574.745   Durbin-Watson:                   0.288
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20404.232
# Skew:                           1.851   Prob(JB):                         0.00
# Kurtosis:                       9.440   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /Users/yujinlee/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1918: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])

# %%
crime_df.to_csv(file_path + '/boston_weekly_data_with_prediction.csv', index=False)
