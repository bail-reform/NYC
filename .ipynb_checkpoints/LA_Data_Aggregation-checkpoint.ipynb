# %%
from shapely.geometry import Point
import pandas as pd
import requests
import geopandas as gpd
from shapely.geometry import Point
from geopy.distance import geodesic, lonlat
import datetime
import matplotlib.pyplot as plt
from tqdm import tqdm
import re
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %% [markdown]
# Crime data (2010-2019): https://data.lacity.org/Public-Safety/Crime-Data-from-2010-to-2019/63jg-8b9z
# <br>Crime data (2020-2023): https://data.lacity.org/Public-Safety/Crime-Data-from-2020-to-Present/2nrs-mtv8
#
# Zipcode geojson file: https://github.com/OpenDataDE/State-zip-code-GeoJSON/blob/master/ca_california_zip_codes_geo.min.json

# %%
file_path = '/Users/yokij/Desktop/Capstone/LA'
df_old = pd.read_csv(file_path + '/LA_2010_to_2019.csv', low_memory = False)
df_new = pd.read_csv(file_path + '/LA_2020_to_Present.csv', low_memory = False)

# %%
df = pd.concat([df_old, df_new], ignore_index=True)
df.columns = map(str.lower, df.columns)
df.columns = df.columns.str.replace(' ', '_')
df['date_occ'] = df['date_occ'].str.slice(0, 10)
df['date_occ'] = pd.to_datetime(df['date_occ'], format='%m/%d/%Y')
df['date_occ'] = df['date_occ'].dt.strftime('%Y-%m-%d')
df.head()
# Out:
#        dr_no               date_rptd    date_occ  time_occ  area_  area_name  \
# 0    1307355  02/20/2010 12:00:00 AM  2010-02-20      1350   13.0     Newton
# 1   11401303  09/13/2010 12:00:00 AM  2010-09-12        45   14.0    Pacific
# 2   70309629  08/09/2010 12:00:00 AM  2010-08-09      1515   13.0     Newton
# 3   90631215  01/05/2010 12:00:00 AM  2010-01-05       150    6.0  Hollywood
# 4  100100501  01/03/2010 12:00:00 AM  2010-01-02      2100    1.0    Central
#
#    rpt_dist_no  part_1-2  crm_cd  \
# 0         1385         2     900
# 1         1485         2     740
# 2         1324         2     946
# 3          646         2     900
# 4          176         1     122
#
#                                          crm_cd_desc  ...   status_desc  \
# 0                           VIOLATION OF COURT ORDER  ...  Adult Arrest
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...   Invest Cont
# 2                          OTHER MISCELLANEOUS CRIME  ...   Invest Cont
# 3                           VIOLATION OF COURT ORDER  ...   Invest Cont
# 4                                    RAPE, ATTEMPTED  ...   Invest Cont
#
#    crm_cd_1 crm_cd_2 crm_cd_3  crm_cd_4  \
# 0     900.0      NaN      NaN       NaN
# 1     740.0      NaN      NaN       NaN
# 2     946.0      NaN      NaN       NaN
# 3     900.0    998.0      NaN       NaN
# 4     122.0      NaN      NaN       NaN
#
#                                   location                     cross_street  \
# 0   300 E  GAGE                         AV                              NaN
# 1          SEPULVEDA                    BL  MANCHESTER                   AV
# 2  1300 E  21ST                         ST                              NaN
# 3          CAHUENGA                     BL  HOLLYWOOD                    BL
# 4          8TH                          ST  SAN PEDRO                    ST
#
#        lat       lon area
# 0  33.9825 -118.2695  NaN
# 1  33.9599 -118.3962  NaN
# 2  34.0224 -118.2524  NaN
# 3  34.1016 -118.3295  NaN
# 4  34.0387 -118.2488  NaN
#
# [5 rows x 29 columns]

# %%
# Filtering dates
df['date_occ'] = pd.to_datetime(df['date_occ'])
threshold_date_from = pd.to_datetime('2018-01-01')
threshold_date_to = pd.to_datetime('2023-05-28')
df = df[threshold_date_to >= df['date_occ']]
df = df[threshold_date_from <= df['date_occ']]
df.head()
# Out:
#              dr_no               date_rptd   date_occ  time_occ  area_  \
# 1609585  180115381  06/04/2018 12:00:00 AM 2018-06-04      1540    1.0
# 1610871  180225137  12/25/2018 12:00:00 AM 2018-12-24      1100    2.0
# 1611007  181314604  06/29/2018 12:00:00 AM 2018-06-26      1200   13.0
# 1611402  180322696  10/07/2018 12:00:00 AM 2018-10-06      1100    3.0
# 1611684  181911558  05/25/2018 12:00:00 AM 2018-05-24       400   19.0
#
#          area_name  rpt_dist_no  part_1-2  crm_cd       crm_cd_desc  ...  \
# 1609585    Central          163         1     648             ARSON  ...
# 1610871    Rampart          236         1     510  VEHICLE - STOLEN  ...
# 1611007     Newton         1363         1     510  VEHICLE - STOLEN  ...
# 1611402  Southwest          398         1     510  VEHICLE - STOLEN  ...
# 1611684    Mission         1917         1     510  VEHICLE - STOLEN  ...
#
#          status_desc  crm_cd_1 crm_cd_2 crm_cd_3  crm_cd_4  \
# 1609585  Invest Cont     648.0      NaN      NaN       NaN
# 1610871  Adult Other     510.0      NaN      NaN       NaN
# 1611007  Invest Cont     510.0      NaN      NaN       NaN
# 1611402  Invest Cont     510.0      NaN      NaN       NaN
# 1611684  Invest Cont     510.0      NaN      NaN       NaN
#
#                                          location  cross_street      lat  \
# 1609585                                       7TH        SPRING  34.0445
# 1610871                                  ALVARADO       MIRAMAR  34.0639
# 1611007   1000 E  51ST                         ST           NaN  33.9966
# 1611402    600 W  VERNON                       AV           NaN  34.0074
# 1611684  14200    POLK                         ST           NaN  34.3139
#
#               lon area
# 1609585 -118.2523  NaN
# 1610871 -118.2721  NaN
# 1611007 -118.2582  NaN
# 1611402 -118.2850  NaN
# 1611684 -118.4427  NaN
#
# [5 rows x 29 columns]

# %%
df['location'] = df.apply(lambda row: f"({row['lat']}, {row['lon']})", axis=1)

# %%
file_path_geo = '/Users/yokij/Desktop/Capstone/LA/ca_california_zip_codes_geo.min.json'
zipcode = gpd.read_file(file_path_geo)
zipcode.head()
# Out:
#   STATEFP10 ZCTA5CE10  GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10   ALAND10  \
# 0        06     94601  0694601        B5   G6350          S   8410939
# 1        06     94501  0694501        B5   G6350          S  20539466
# 2        06     94560  0694560        B5   G6350          S  35757865
# 3        06     94587  0694587        B5   G6350          S  51075108
# 4        06     94580  0694580        B5   G6350          S   8929836
#
#    AWATER10   INTPTLAT10    INTPTLON10 PARTFLG10  \
# 0    310703  +37.7755447  -122.2187049         N
# 1   9005303  +37.7737968  -122.2781230         N
# 2     60530  +37.5041413  -122.0323587         N
# 3         0  +37.6031556  -122.0186382         N
# 4     17052  +37.6757312  -122.1330170         N
#
#                                             geometry
# 0  POLYGON ((-122.22717 37.79197, -122.22693 37.7...
# 1  POLYGON ((-122.29181 37.76301, -122.30661 37.7...
# 2  POLYGON ((-122.05499 37.54959, -122.05441 37.5...
# 3  POLYGON ((-122.06515 37.60485, -122.06499 37.6...
# 4  POLYGON ((-122.12999 37.68445, -122.12995 37.6...

# %%
def create_point_from_string(coord_str):
    match = re.match(r'\(([^,]+), ([^)]+)\)', coord_str)
    if match:
        lat, lon = map(float, match.groups())
        return Point(lon, lat)
    return None

# %%
df['geometry'] = df['location'].apply(create_point_from_string)

# %%
gdf = gpd.GeoDataFrame(df, geometry='geometry')
gdf.head()
# Out:
#              dr_no               date_rptd   date_occ  time_occ  area_  \
# 1609585  180115381  06/04/2018 12:00:00 AM 2018-06-04      1540    1.0
# 1610871  180225137  12/25/2018 12:00:00 AM 2018-12-24      1100    2.0
# 1611007  181314604  06/29/2018 12:00:00 AM 2018-06-26      1200   13.0
# 1611402  180322696  10/07/2018 12:00:00 AM 2018-10-06      1100    3.0
# 1611684  181911558  05/25/2018 12:00:00 AM 2018-05-24       400   19.0
#
#          area_name  rpt_dist_no  part_1-2  crm_cd       crm_cd_desc  ...  \
# 1609585    Central          163         1     648             ARSON  ...
# 1610871    Rampart          236         1     510  VEHICLE - STOLEN  ...
# 1611007     Newton         1363         1     510  VEHICLE - STOLEN  ...
# 1611402  Southwest          398         1     510  VEHICLE - STOLEN  ...
# 1611684    Mission         1917         1     510  VEHICLE - STOLEN  ...
#
#         crm_cd_1  crm_cd_2 crm_cd_3 crm_cd_4              location  \
# 1609585    648.0       NaN      NaN      NaN  (34.0445, -118.2523)
# 1610871    510.0       NaN      NaN      NaN  (34.0639, -118.2721)
# 1611007    510.0       NaN      NaN      NaN  (33.9966, -118.2582)
# 1611402    510.0       NaN      NaN      NaN   (34.0074, -118.285)
# 1611684    510.0       NaN      NaN      NaN  (34.3139, -118.4427)
#
#         cross_street      lat       lon area                     geometry
# 1609585       SPRING  34.0445 -118.2523  NaN  POINT (-118.25230 34.04450)
# 1610871      MIRAMAR  34.0639 -118.2721  NaN  POINT (-118.27210 34.06390)
# 1611007          NaN  33.9966 -118.2582  NaN  POINT (-118.25820 33.99660)
# 1611402          NaN  34.0074 -118.2850  NaN  POINT (-118.28500 34.00740)
# 1611684          NaN  34.3139 -118.4427  NaN  POINT (-118.44270 34.31390)
#
# [5 rows x 30 columns]

# %%
gdf.set_crs(epsg=4326, inplace=True)
zipcode.set_crs(epsg=4326, inplace=True)
result = gpd.sjoin(gdf, zipcode, how="left", op='within')
# Out:
# /Users/yokij/opt/anaconda3/lib/python3.9/site-packages/geopandas/sindex.py:87: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i, (idx, item) in enumerate(geometry.iteritems())

# %%
result.set_index('date_occ', inplace=True)

# %%
result.index = pd.to_datetime(result.index)
result.head()
# Out:
#                 dr_no               date_rptd  time_occ  area_  area_name  \
# date_occ
# 2018-06-04  180115381  06/04/2018 12:00:00 AM      1540    1.0    Central
# 2018-12-24  180225137  12/25/2018 12:00:00 AM      1100    2.0    Rampart
# 2018-06-26  181314604  06/29/2018 12:00:00 AM      1200   13.0     Newton
# 2018-10-06  180322696  10/07/2018 12:00:00 AM      1100    3.0  Southwest
# 2018-05-24  181911558  05/25/2018 12:00:00 AM       400   19.0    Mission
#
#             rpt_dist_no  part_1-2  crm_cd       crm_cd_desc    mocodes  ...  \
# date_occ                                                                ...
# 2018-06-04          163         1     648             ARSON  0329 2004  ...
# 2018-12-24          236         1     510  VEHICLE - STOLEN        NaN  ...
# 2018-06-26         1363         1     510  VEHICLE - STOLEN        NaN  ...
# 2018-10-06          398         1     510  VEHICLE - STOLEN        NaN  ...
# 2018-05-24         1917         1     510  VEHICLE - STOLEN        NaN  ...
#
#             ZCTA5CE10  GEOID10 CLASSFP10  MTFCC10 FUNCSTAT10      ALAND10  \
# date_occ
# 2018-06-04      90014  0690014        B5    G6350          S     733437.0
# 2018-12-24      90057  0690057        B5    G6350          S    2293706.0
# 2018-06-26      90011  0690011        B5    G6350          S   11100424.0
# 2018-10-06      90037  0690037        B5    G6350          S    7351184.0
# 2018-05-24      91342  0691342        B5    G6350          S  142711370.0
#
#             AWATER10   INTPTLAT10    INTPTLON10  PARTFLG10
# date_occ
# 2018-06-04       0.0  +34.0431457  -118.2517464          N
# 2018-12-24   34211.0  +34.0617348  -118.2767572          N
# 2018-06-26     529.0  +34.0070900  -118.2586805          N
# 2018-10-06       0.0  +34.0027226  -118.2874866          N
# 2018-05-24  710812.0  +34.3266744  -118.3822622          N
#
# [5 rows x 41 columns]

# %%
weekly_data = result.groupby('ZCTA5CE10').resample('W').size().reset_index(name='total_count')

# %%
weekly_data['ZCTA5CE10'].unique().shape
# Out:
# (151,)

# %% [markdown]
# # Population

# %% [markdown]
# ACS2022 https://data.census.gov/table/ACSDP5Y2022.DP05?g=050XX00US06037$8600000

# %%
pop = pd.read_csv('/Users/yokij/Desktop/Capstone/LA/LA_ACSDP5Y2022DP05.csv', low_memory = False)
pop.head()
# Out:
#            GEO_ID                  NAME  \
# 0       Geography  Geographic Area Name
# 1  860Z200US90001           ZCTA5 90001
# 2  860Z200US90002           ZCTA5 90002
# 3  860Z200US90003           ZCTA5 90003
# 4  860Z200US90004           ZCTA5 90004
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                    57652
# 2                                    53108
# 3                                    75024
# 4                                    58833
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                            2615
# 2                                            2472
# 3                                            3354
# 4                                            2270
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                          29102
# 2                                          26040
# 3                                          37793
# 4                                          29865
#
#                                           DP05_0002M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               1541
# 2                                               1537
# 3                                               2061
# 4                                               1410
#
#                                         DP05_0003E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Female
# 1                                            28550
# 2                                            27068
# 3                                            37231
# 4                                            28968
#
#                                           DP05_0003M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               1636
# 2                                               1300
# 3                                               1702
# 4                                               1330
#
#                                           DP05_0004E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Sex r...
# 1                                              101.9
# 2                                               96.2
# 3                                              101.5
# 4                                              103.1
#
#                                           DP05_0004M  ...  \
# 0  Margin of Error!!SEX AND AGE!!Total population...  ...
# 1                                                6.4  ...
# 2                                                5.1  ...
# 3                                                4.7  ...
# 4                                                5.4  ...
#
#                                          DP05_0087PM  \
# 0  Percent Margin of Error!!HISPANIC OR LATINO AN...
# 1                                                0.3
# 2                                                0.2
# 3                                                0.1
# 4                                                0.7
#
#                     DP05_0088PE                                   DP05_0088PM  \
# 0  Percent!!Total housing units  Percent Margin of Error!!Total housing units
# 1                           (X)                                           (X)
# 2                           (X)                                           (X)
# 3                           (X)                                           (X)
# 4                           (X)                                           (X)
#
#                                          DP05_0089PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                              25411
# 2                                              25979
# 3                                              31241
# 4                                              33010
#
#                                          DP05_0089PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          DP05_0090PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               50.2
# 2                                               46.1
# 3                                               45.5
# 4                                               50.6
#
#                                          DP05_0090PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                2.4
# 2                                                2.1
# 3                                                1.9
# 4                                                1.8
#
#                                          DP05_0091PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               49.8
# 2                                               53.9
# 3                                               54.5
# 4                                               49.4
#
#                                          DP05_0091PM Unnamed: 366
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...          NaN
# 1                                                2.4          NaN
# 2                                                2.1          NaN
# 3                                                1.9          NaN
# 4                                                1.8          NaN
#
# [5 rows x 367 columns]

# %%
pop = pop[['NAME', 'DP05_0001E']]
pop = pop.rename(columns={"NAME": "ZCTA5CE10"})
pop = pop.rename(columns={"DP05_0001E": "total_population"})
pop['ZCTA5CE10'] = pop['ZCTA5CE10'].str.replace('ZCTA5 ', '')
pop = pop.drop(0)
pop.head()
# Out:
#   ZCTA5CE10 total_population
# 1     90001            57652
# 2     90002            53108
# 3     90003            75024
# 4     90004            58833
# 5     90005            37754

# %%
pop['total_population'] = pd.to_numeric(pop['total_population'], errors='coerce')
total_population_sum = pop['total_population'].sum()
total_population_sum
# Out:
# 10286146

# %%
weekly_data['ZCTA5CE10'] = weekly_data['ZCTA5CE10'].astype(str).str.zfill(5)

# %%
merged_df = pd.merge(weekly_data, pop, on='ZCTA5CE10', how='left')
merged_df.head()
# Out:
#   ZCTA5CE10   date_occ  total_count  total_population
# 0     90001 2018-01-07           21           57652.0
# 1     90001 2018-01-14           14           57652.0
# 2     90001 2018-01-21           17           57652.0
# 3     90001 2018-01-28           16           57652.0
# 4     90001 2018-02-04           23           57652.0

# %%
merged_df = merged_df[merged_df['total_population'] != 0]

# %%
merged_df.shape
# Out:
# (39274, 4)

# %%
merged_df.loc[3, 'total_population'] = pd.NA
merged_df = merged_df.dropna(subset=['total_population'])

# %%
merged_df.shape
# Out:
# (38995, 4)

# %%
merged_df['total_population'] = merged_df['total_population'].astype(str)
merged_df['total_population'] = pd.to_numeric(merged_df['total_population'].str.replace(',', ''), errors='coerce').fillna(0).astype(int)
merged_df['crime_rate'] = (merged_df['total_count'] / merged_df['total_population']) * 10000
merged_df = merged_df.rename(columns={'date_occ': 'week'})
merged_df['week'] = pd.to_datetime(merged_df['week'])

# %%
merged_df.tail()
# Out:
#       ZCTA5CE10       week  total_count  total_population  crime_rate
# 39958     91801 2021-04-18            0             53320    0.000000
# 39959     91801 2021-04-25            0             53320    0.000000
# 39960     91801 2021-05-02            0             53320    0.000000
# 39961     91801 2021-05-09            1             53320    0.187547
# 39962     91803 2018-07-15            1             29006    0.344756

# %%
df_plot = merged_df
df_plot.set_index('week', inplace=True)

plt.figure(figsize=(12, 8))
plt.plot(df_plot.index, df_plot['crime_rate'], marker='o', linestyle='None', color='b', markersize=1)

plt.title('Crime Rates Over Time')
plt.xlabel('Week')
plt.ylabel('Crime Rate')
plt.grid(True, linewidth=0.5)
plt.show()

# %%
#zoom in
plt.figure(figsize=(12, 8))
plt.plot(df_plot.index, df_plot['crime_rate'], marker='o', linestyle='None', color='b', markersize=1)

plt.ylim(0, 50)

plt.title('Crime Rates Over Time')
plt.xlabel('Week')
plt.ylabel('Crime Rate')
plt.grid(True, linewidth=0.5)
plt.show()

# %%
statistics = merged_df.describe().T
print(statistics)
# Out:
#                     count          mean           std   min           25%  \
# total_count       38995.0     30.311142     26.885853   0.0      6.000000
# total_population  38995.0  35923.913014  20692.876322  56.0  22078.000000
# crime_rate        38995.0     11.793336     28.378049   0.0      3.295636
#
#                            50%          75%            max
# total_count          27.000000     47.00000     189.000000
# total_population  32965.000000  47682.00000  106042.000000
# crime_rate            7.960991     11.48018     892.857143

# %%
merged_df['ZCTA5CE10'].nunique()
# Out:
# 147

# %%
merged_df.to_csv('merged_df.csv')

# %%
print(merged_df['total_count'].median())
print(merged_df['total_population'].median())
print(merged_df['crime_rate'].median())
# Out:
# 27.0
# 32965.0
# 7.960991143397353

# %% [markdown]
# # S2301 Employment

# %% [markdown]
# ACS2018 https://data.census.gov/table/ACSST5Y2018.S2301?g=050XX00US06037$8600000

# %%
crime = merged_df.reset_index()
crime.tail()
# Out:
#             week ZCTA5CE10  total_count  total_population  crime_rate
# 38990 2021-04-18     91801            0             53320    0.000000
# 38991 2021-04-25     91801            0             53320    0.000000
# 38992 2021-05-02     91801            0             53320    0.000000
# 38993 2021-05-09     91801            1             53320    0.187547
# 38994 2018-07-15     91803            1             29006    0.344756

# %%
file_path = '/Users/yokij/Desktop/Capstone/LA/LA_ACSST5Y2018S2301.csv'
df = pd.read_csv(file_path, low_memory=False)
employment = df[['NAME', 'S2301_C03_001E', 'S2301_C04_001E']]
employment = employment.iloc[1:].reset_index(drop=True)
employment.columns = ['ZCTA5CE10', 'e/pop_rate', 'un_rate']
employment['ZCTA5CE10'] = employment['ZCTA5CE10'].str.replace('ZCTA5 ', '')
employment.head()
# Out:
#   ZCTA5CE10 e/pop_rate un_rate
# 0     90001       56.1     9.7
# 1     90002       51.9    10.3
# 2     90003       55.2    10.5
# 3     90004       66.7     4.8
# 4     90005       65.5     7.2

# %%
employment = employment.replace('-', pd.NA)
employment = employment.dropna()

# %%
crime = crime.merge(employment, on = 'ZCTA5CE10', how = 'right')
crime.head()
# Out:
#         week ZCTA5CE10  total_count  total_population  crime_rate e/pop_rate  \
# 0 2018-01-07     90001         21.0           57652.0    3.642545       56.1
# 1 2018-01-14     90001         14.0           57652.0    2.428363       56.1
# 2 2018-01-21     90001         17.0           57652.0    2.948727       56.1
# 3 2018-02-04     90001         23.0           57652.0    3.989454       56.1
# 4 2018-02-11     90001         15.0           57652.0    2.601818       56.1
#
#   un_rate
# 0     9.7
# 1     9.7
# 2     9.7
# 3     9.7
# 4     9.7

# %% [markdown]
# # S1701 poverty

# %% [markdown]
# https://data.census.gov/table/ACSST5Y2018.S1701?g=050XX00US06037$8600000

# %%
file_path = '/Users/yokij/Desktop/Capstone/LA/LA_ACSST5Y2018S1701.csv'
df = pd.read_csv(file_path, low_memory=False)
poverty = df[['NAME', 'S1701_C03_001E']]
poverty = poverty.iloc[1:].reset_index(drop=True)
poverty.columns = ['ZCTA5CE10', 'p_rate']
poverty['ZCTA5CE10'] = poverty['ZCTA5CE10'].str.replace('ZCTA5 ', '')
poverty.head()
# Out:
#   ZCTA5CE10 p_rate
# 0     90001   28.8
# 1     90002   32.9
# 2     90003   30.7
# 3     90004   18.1
# 4     90005   28.1

# %%
poverty = poverty.replace('-', pd.NA)
poverty = poverty.dropna()

# %%
crime = crime.merge(poverty, on = 'ZCTA5CE10', how = 'outer')
crime.head()
# Out:
#         week ZCTA5CE10  total_count  total_population  crime_rate e/pop_rate  \
# 0 2018-01-07     90001         21.0           57652.0    3.642545       56.1
# 1 2018-01-14     90001         14.0           57652.0    2.428363       56.1
# 2 2018-01-21     90001         17.0           57652.0    2.948727       56.1
# 3 2018-02-04     90001         23.0           57652.0    3.989454       56.1
# 4 2018-02-11     90001         15.0           57652.0    2.601818       56.1
#
#   un_rate p_rate
# 0     9.7   28.8
# 1     9.7   28.8
# 2     9.7   28.8
# 3     9.7   28.8
# 4     9.7   28.8

# %% [markdown]
# # S1901 Household Income

# %% [markdown]
# https://data.census.gov/table/ACSST5Y2018.S1901?g=050XX00US06037$8600000

# %%
file_path = '/Users/yokij/Desktop/Capstone/LA/LA_ACSST5Y2018S1901.csv'
df = pd.read_csv(file_path, low_memory=False)
HI = df[['NAME', 'S1901_C01_012E', 'S1901_C01_013E']]
HI = HI.iloc[1:].reset_index(drop=True)
HI.columns = ['ZCTA5CE10', 'in_median', 'in_mean']
HI['ZCTA5CE10'] = HI['ZCTA5CE10'].str.replace('ZCTA5 ', '')
HI.head()
# Out:
#   ZCTA5CE10 in_median in_mean
# 0     90001     38521   49526
# 1     90002     35410   46741
# 2     90003     37226   47313
# 3     90004     48754   82746
# 4     90005     35149   51847

# %%
HI = HI.replace('-', pd.NA)
HI = HI.dropna()

# %%
crime = crime.merge(HI, on = 'ZCTA5CE10', how = 'outer')
crime.head(115)
# Out:
#           week ZCTA5CE10  total_count  total_population  crime_rate  \
# 0   2018-01-07     90001         21.0           57652.0    3.642545
# 1   2018-01-14     90001         14.0           57652.0    2.428363
# 2   2018-01-21     90001         17.0           57652.0    2.948727
# 3   2018-02-04     90001         23.0           57652.0    3.989454
# 4   2018-02-11     90001         15.0           57652.0    2.601818
# ..         ...       ...          ...               ...         ...
# 110 2020-02-23     90001         16.0           57652.0    2.775272
# 111 2020-03-01     90001         11.0           57652.0    1.908000
# 112 2020-03-08     90001         12.0           57652.0    2.081454
# 113 2020-03-15     90001         12.0           57652.0    2.081454
# 114 2020-03-22     90001         12.0           57652.0    2.081454
#
#     e/pop_rate un_rate p_rate in_median in_mean
# 0         56.1     9.7   28.8     38521   49526
# 1         56.1     9.7   28.8     38521   49526
# 2         56.1     9.7   28.8     38521   49526
# 3         56.1     9.7   28.8     38521   49526
# 4         56.1     9.7   28.8     38521   49526
# ..         ...     ...    ...       ...     ...
# 110       56.1     9.7   28.8     38521   49526
# 111       56.1     9.7   28.8     38521   49526
# 112       56.1     9.7   28.8     38521   49526
# 113       56.1     9.7   28.8     38521   49526
# 114       56.1     9.7   28.8     38521   49526
#
# [115 rows x 10 columns]

# %%
crime.loc[2, 'week'] = pd.NA  
crime = crime.dropna(subset=['week'])
crime.loc[7, 'e/pop_rate'] = pd.NA  
crime = crime.dropna(subset=['e/pop_rate'])
crime.loc[8, 'un_rate'] = pd.NA  
crime = crime.dropna(subset=['un_rate'])
crime.loc[9, 'p_rate'] = pd.NA  
crime = crime.dropna(subset=['p_rate'])
crime.loc[10, 'in_median'] = pd.NA  
crime = crime.dropna(subset=['in_median'])

# %%
crime.shape
# Out:
# (37584, 10)

# %%
crime.to_csv('LA_weekly_data.csv', index=False)

# %% [markdown]
# # Covid

# %% [markdown]
# http://dashboard.publichealth.lacounty.gov/covid19_surveillance_dashboard/
# https://www.laalmanac.com/health/he999c.php

# %%
file_path = '/Users/yokij/Desktop/Capstone/LA/LA_County_Covid19_cases_deaths_date_table.csv'
covid = pd.read_csv(file_path, low_memory=False)
covid['date_use'] = pd.to_datetime(covid['date_use'], errors='coerce')
covid = covid[(covid['date_use'] >= pd.Timestamp('2018-01-01')) & (covid['date_use'] <= pd.Timestamp('2023-05-28'))]
covid = covid.rename(columns={"date_use": "week"})
covid.tail(10)
# Out:
#       Unnamed: 0       week  total_cases  new_case  avg_cases  total_deaths  \
# 1443        1444 2020-03-10          665        99       54.0             0
# 1444        1445 2020-03-09          566        90       42.0             0
# 1445        1446 2020-03-08          476        49       31.0             0
# 1446        1447 2020-03-07          427        41       28.0             0
# 1447        1448 2020-03-06          386        44        NaN             0
# 1448        1449 2020-03-05          342        34        NaN             0
# 1449        1450 2020-03-04          308        19        NaN             0
# 1450        1451 2020-03-03          289        14        NaN             0
# 1451        1452 2020-03-02          275        19        NaN             0
# 1452        1453 2020-03-01          256        25        NaN             0
#
#       new_deaths  avg_deaths
# 1443           0         0.0
# 1444           0         0.0
# 1445           0         0.0
# 1446           0         0.0
# 1447           0         NaN
# 1448           0         NaN
# 1449           0         NaN
# 1450           0         NaN
# 1451           0         NaN
# 1452           0         NaN

# %%
covid.set_index('week', inplace=True)
covid = covid.resample('W').sum()['new_case']
covid = covid.reset_index()
covid.tail()
# Out:
#           week  new_case
# 166 2023-05-07      2160
# 167 2023-05-14      2148
# 168 2023-05-21      1888
# 169 2023-05-28      1662
# 170 2023-06-04      1560

# %% [markdown]
# # Regression

# %%
crime = crime.merge(covid, on = 'week', how = 'left')
crime.head()
# Out:
#         week ZCTA5CE10  total_count  total_population  crime_rate e/pop_rate  \
# 0 2018-01-07     90001         21.0           57652.0    3.642545       56.1
# 1 2018-01-14     90001         14.0           57652.0    2.428363       56.1
# 2 2018-02-04     90001         23.0           57652.0    3.989454       56.1
# 3 2018-02-11     90001         15.0           57652.0    2.601818       56.1
# 4 2018-02-18     90001         21.0           57652.0    3.642545       56.1
#
#   un_rate p_rate in_median in_mean  new_case
# 0     9.7   28.8     38521   49526       NaN
# 1     9.7   28.8     38521   49526       NaN
# 2     9.7   28.8     38521   49526       NaN
# 3     9.7   28.8     38521   49526       NaN
# 4     9.7   28.8     38521   49526       NaN

# %%
crime['caserate'] = (crime['new_case'] / 10286146) * 10000
crime["new_case"].fillna(0, inplace=True)
crime["caserate"].fillna(0, inplace=True)
crime.head()
# Out:
#         week ZCTA5CE10  total_count  total_population  crime_rate e/pop_rate  \
# 0 2018-01-07     90001         21.0           57652.0    3.642545       56.1
# 1 2018-01-14     90001         14.0           57652.0    2.428363       56.1
# 2 2018-02-04     90001         23.0           57652.0    3.989454       56.1
# 3 2018-02-11     90001         15.0           57652.0    2.601818       56.1
# 4 2018-02-18     90001         21.0           57652.0    3.642545       56.1
#
#   un_rate p_rate in_median in_mean  new_case  caserate
# 0     9.7   28.8     38521   49526       0.0       0.0
# 1     9.7   28.8     38521   49526       0.0       0.0
# 2     9.7   28.8     38521   49526       0.0       0.0
# 3     9.7   28.8     38521   49526       0.0       0.0
# 4     9.7   28.8     38521   49526       0.0       0.0

# %%
min_date = crime['week'].min()
crime['week_no'] = ((crime['week'] - min_date).dt.days // 7) + 1

# %%
crime.to_csv('LA_weekly_data.csv', index=False)

# %%
crime['in_median'] = crime['in_median'].astype(str)
crime['in_median'] = crime['in_median'].replace('250,000+', '250000')
crime['week_no'] = pd.to_numeric(crime['week_no'], errors='coerce')
crime['p_rate'] = pd.to_numeric(crime['p_rate'], errors='coerce')
crime['e/pop_rate'] = pd.to_numeric(crime['e/pop_rate'], errors='coerce')
crime['un_rate'] = pd.to_numeric(crime['un_rate'], errors='coerce')
crime['in_median'] = pd.to_numeric(crime['in_median'], errors='coerce')
crime['in_mean'] = pd.to_numeric(crime['in_mean'], errors='coerce')
crime['caserate'] = pd.to_numeric(crime['caserate'], errors='coerce')

crime.dropna(subset=['p_rate', 'un_rate', 'in_median', 'crime_rate'], inplace=True)

X = crime[['week_no', 'p_rate', 'un_rate', 'in_median', 'caserate']] 
Y = crime['crime_rate']

model = sm.OLS(Y, X).fit()
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             crime_rate   R-squared (uncentered):                   0.453
# Model:                            OLS   Adj. R-squared (uncentered):              0.453
# Method:                 Least Squares   F-statistic:                              6229.
# Date:                Sat, 02 Mar 2024   Prob (F-statistic):                        0.00
# Time:                        02:12:20   Log-Likelihood:                     -1.4820e+05
# No. Observations:               37584   AIC:                                  2.964e+05
# Df Residuals:                   37579   BIC:                                  2.964e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# week_no       -0.0019      0.001     -2.293      0.022      -0.003      -0.000
# p_rate         0.6167      0.009     65.882      0.000       0.598       0.635
# un_rate       -0.0704      0.032     -2.181      0.029      -0.134      -0.007
# in_median   1.435e-06   1.66e-06      0.865      0.387   -1.82e-06    4.69e-06
# caserate      -0.0051      0.002     -2.374      0.018      -0.009      -0.001
# ==============================================================================
# Omnibus:                    47265.008   Durbin-Watson:                   0.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8419436.520
# Skew:                           6.939   Prob(JB):                         0.00
# Kurtosis:                      74.999   Cond. No.                     3.99e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 3.99e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
crime['y_hat'] = model.predict(X)

# %%
crime.head()
# Out:
#         week ZCTA5CE10  total_count  total_population  crime_rate  e/pop_rate  \
# 0 2018-01-07     90001         21.0           57652.0    3.642545        56.1
# 1 2018-01-14     90001         14.0           57652.0    2.428363        56.1
# 2 2018-02-04     90001         23.0           57652.0    3.989454        56.1
# 3 2018-02-11     90001         15.0           57652.0    2.601818        56.1
# 4 2018-02-18     90001         21.0           57652.0    3.642545        56.1
#
#    un_rate  p_rate  in_median  in_mean  new_case  caserate  week_no      y_hat
# 0      9.7    28.8      38521    49526       0.0       0.0        1  17.131961
# 1      9.7    28.8      38521    49526       0.0       0.0        2  17.130103
# 2      9.7    28.8      38521    49526       0.0       0.0        5  17.124531
# 3      9.7    28.8      38521    49526       0.0       0.0        6  17.122673
# 4      9.7    28.8      38521    49526       0.0       0.0        7  17.120816

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37584 entries, 0 to 37583
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   week              37584 non-null  datetime64[ns]
#  1   ZCTA5CE10         37584 non-null  object
#  2   total_count       37584 non-null  float64
#  3   total_population  37584 non-null  float64
#  4   crime_rate        37584 non-null  float64
#  5   e/pop_rate        37584 non-null  float64
#  6   un_rate           37584 non-null  float64
#  7   p_rate            37584 non-null  float64
#  8   in_median         37584 non-null  int64
#  9   in_mean           37584 non-null  int64
#  10  new_case          37584 non-null  float64
#  11  caserate          37584 non-null  float64
#  12  week_no           37584 non-null  int64
#  13  y_hat             37584 non-null  float64
# dtypes: datetime64[ns](1), float64(9), int64(3), object(1)
# memory usage: 4.3+ MB

# %%
crime.to_csv('LA_weekly_data.csv', index=False)
